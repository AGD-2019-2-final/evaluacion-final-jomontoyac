# %%
# %load_ext bigdata
# !rm -rf output

# %%
# %%pig
# tabla = LOAD 'data.tsv' USING PigStorage('\t')
#     AS (f1:CHARARRAY
#         ,f2:BAG{t:TUPLE(p:CHARARRAY)}
#         ,f3:MAP[]
#         );
# Out:
#  tabla = LOAD 'data.tsv' USING PigStorage('\t')
#     AS (f1:CHARARRAY
#         ,f2:BAG{t:TUPLE(p:CHARARRAY)}
#         ,f3:MAP[]
#         );

# %%
# %%pig
#
# filtro = FOREACH tabla GENERATE FLATTEN(f3);
# grouped = GROUP filtro by $0;
# conteo = FOREACH grouped GENERATE $0, COUNT(filtro);
# STORE conteo INTO 'output' USING PigStorage(',');
# Out:
#  filtro = FOREACH tabla GENERATE FLATTEN(f3);
#  grouped = GROUP filtro by $0;
#  conteo = FOREACH grouped GENERATE $0, COUNT(filtro);
#  STORE conteo INTO 'output' USING PigStorage(',');
# 2020-01-24 00:07:02,715 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-24 00:07:02,867 [JobControl] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-24 00:07:02,889 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-24 00:07:03,009 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-24 00:07:03,014 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-01-24 00:07:03,050 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local470032214_0002
# 2020-01-24 00:07:03,289 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1579824423112/pig-0.17.0-core-h2.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/pig-0.17.0-core-h2.jar
# 2020-01-24 00:07:03,295 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1579824423112/pig-0.17.0-core-h2.jar /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/pig-0.17.0-core-h2.jar' failed 1 with: ln: failed to create symbolic link '/datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/pig-0.17.0-core-h2.jar': Protocol error
#
# 2020-01-24 00:07:03,296 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1579824423112/pig-0.17.0-core-h2.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/pig-0.17.0-core-h2.jar
# 2020-01-24 00:07:03,296 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp1431203008/tmp2112734824/pig-0.17.0-core-h2.jar as file:/tmp/hadoop-root/mapred/local/1579824423112/pig-0.17.0-core-h2.jar
# 2020-01-24 00:07:03,297 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1579824423113/automaton-1.11-8.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/automaton-1.11-8.jar
# 2020-01-24 00:07:03,301 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1579824423113/automaton-1.11-8.jar /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/automaton-1.11-8.jar' failed 1 with: ln: failed to create symbolic link '/datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/automaton-1.11-8.jar': Protocol error
#
# 2020-01-24 00:07:03,301 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1579824423113/automaton-1.11-8.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/automaton-1.11-8.jar
# 2020-01-24 00:07:03,301 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp1431203008/tmp-552448815/automaton-1.11-8.jar as file:/tmp/hadoop-root/mapred/local/1579824423113/automaton-1.11-8.jar
# 2020-01-24 00:07:03,303 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1579824423114/antlr-runtime-3.4.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/antlr-runtime-3.4.jar
# 2020-01-24 00:07:03,308 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1579824423114/antlr-runtime-3.4.jar /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/antlr-runtime-3.4.jar' failed 1 with: ln: failed to create symbolic link '/datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/antlr-runtime-3.4.jar': Protocol error
#
# 2020-01-24 00:07:03,308 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1579824423114/antlr-runtime-3.4.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/antlr-runtime-3.4.jar
# 2020-01-24 00:07:03,308 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp1431203008/tmp1514259700/antlr-runtime-3.4.jar as file:/tmp/hadoop-root/mapred/local/1579824423114/antlr-runtime-3.4.jar
# 2020-01-24 00:07:03,309 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1579824423115/joda-time-2.9.3.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/joda-time-2.9.3.jar
# 2020-01-24 00:07:03,316 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1579824423115/joda-time-2.9.3.jar /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/joda-time-2.9.3.jar' failed 1 with: ln: failed to create symbolic link '/datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/joda-time-2.9.3.jar': Protocol error
#
# 2020-01-24 00:07:03,316 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1579824423115/joda-time-2.9.3.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/joda-time-2.9.3.jar
# 2020-01-24 00:07:03,316 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp1431203008/tmp-1061313357/joda-time-2.9.3.jar as file:/tmp/hadoop-root/mapred/local/1579824423115/joda-time-2.9.3.jar
# 2020-01-24 00:07:03,409 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1579824423112/pig-0.17.0-core-h2.jar
# 2020-01-24 00:07:03,409 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1579824423113/automaton-1.11-8.jar
# 2020-01-24 00:07:03,409 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1579824423114/antlr-runtime-3.4.jar
# 2020-01-24 00:07:03,409 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1579824423115/joda-time-2.9.3.jar
# 2020-01-24 00:07:03,410 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2020-01-24 00:07:03,412 [Thread-53] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2020-01-24 00:07:03,447 [Thread-53] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-01-24 00:07:03,451 [Thread-53] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2020-01-24 00:07:03,451 [Thread-53] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-01-24 00:07:03,453 [Thread-53] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-01-24 00:07:03,453 [Thread-53] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-01-24 00:07:03,453 [Thread-53] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2020-01-24 00:07:03,480 [Thread-53] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2020-01-24 00:07:03,481 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local470032214_0002_m_000000_0
# 2020-01-24 00:07:03,508 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-01-24 00:07:03,508 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-01-24 00:07:03,508 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2020-01-24 00:07:03,511 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 1741
# Input split[0]:
#    Length = 1741
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2020-01-24 00:07:03,556 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2020-01-24 00:07:03,556 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2020-01-24 00:07:03,556 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2020-01-24 00:07:03,556 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2020-01-24 00:07:03,557 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2020-01-24 00:07:03,558 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2020-01-24 00:07:03,624 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2020-01-24 00:07:03,624 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2020-01-24 00:07:03,624 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2020-01-24 00:07:03,624 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 2450; bufvoid = 104857600
# 2020-01-24 00:07:03,624 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26213700(104854800); length = 697/6553600
# 2020-01-24 00:07:03,655 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2020-01-24 00:07:03,657 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local470032214_0002_m_000000_0 is done. And is in the process of committing
# 2020-01-24 00:07:03,663 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2020-01-24 00:07:03,663 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local470032214_0002_m_000000_0' done.
# 2020-01-24 00:07:03,664 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local470032214_0002_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=11606434
# 		FILE: Number of bytes written=24189018
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=40
# 		Map output records=175
# 		Map output bytes=2450
# 		Map output materialized bytes=176
# 		Input split bytes=402
# 		Combine input records=175
# 		Combine output records=10
# 		Spilled Records=10
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=395313152
# 	File Input Format Counters
# 		Bytes Read=0
# 2020-01-24 00:07:03,665 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local470032214_0002_m_000000_0
# 2020-01-24 00:07:03,665 [Thread-53] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2020-01-24 00:07:03,667 [Thread-53] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2020-01-24 00:07:03,667 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local470032214_0002_r_000000_0
# 2020-01-24 00:07:03,690 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-01-24 00:07:03,690 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-01-24 00:07:03,694 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2020-01-24 00:07:03,695 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@8bdd1c2
# 2020-01-24 00:07:03,696 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=652528832, maxSingleShuffleLimit=163132208, mergeThreshold=430669056, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2020-01-24 00:07:03,702 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local470032214_0002_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2020-01-24 00:07:03,708 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#2 about to shuffle output of map attempt_local470032214_0002_m_000000_0 decomp: 172 len: 176 to MEMORY
# 2020-01-24 00:07:03,711 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 172 bytes from map-output for attempt_local470032214_0002_m_000000_0
# 2020-01-24 00:07:03,711 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 172, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->172
# 2020-01-24 00:07:03,713 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2020-01-24 00:07:03,714 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2020-01-24 00:07:03,714 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2020-01-24 00:07:03,717 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2020-01-24 00:07:03,717 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 161 bytes
# 2020-01-24 00:07:03,719 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 172 bytes to disk to satisfy reduce memory limit
# 2020-01-24 00:07:03,719 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 176 bytes from disk
# 2020-01-24 00:07:03,719 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2020-01-24 00:07:03,719 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2020-01-24 00:07:03,720 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 161 bytes
# 2020-01-24 00:07:03,721 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2020-01-24 00:07:03,725 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-01-24 00:07:03,725 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-01-24 00:07:03,848 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local470032214_0002_r_000000_0 is done. And is in the process of committing
# 2020-01-24 00:07:03,870 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2020-01-24 00:07:03,870 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local470032214_0002_r_000000_0 is allowed to commit now
# 2020-01-24 00:07:03,918 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local470032214_0002_r_000000_0' to file:/datalake/evaluacion-final-jomontoyac-master/02-pig-50/q06-10/output/_temporary/0/task_local470032214_0002_r_000000
# 2020-01-24 00:07:03,920 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2020-01-24 00:07:03,921 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local470032214_0002_r_000000_0' done.
# 2020-01-24 00:07:03,921 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local470032214_0002_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=11606818
# 		FILE: Number of bytes written=24189276
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=10
# 		Reduce shuffle bytes=176
# 		Reduce input records=10
# 		Reduce output records=10
# 		Spilled Records=10
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=395313152
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2020-01-24 00:07:03,922 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local470032214_0002_r_000000_0
# 2020-01-24 00:07:03,922 [Thread-53] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2020-01-24 00:07:08,443 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-24 00:07:08,445 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-24 00:07:08,446 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-24 00:07:08,461 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-24 00:07:08,463 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-24 00:07:08,465 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
