# %%
# %load_ext bigdata

# %%
# !rm -rf output

# %%
# %%pig
#
# u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
# Out:
#  u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);

# %%
# %%pig
#
# --
# -- >>> Escriba su respuesta a partir de este punto <<<
# --
# datos = FOREACH u GENERATE
#         birthday AS fecha,
#         ToString(ToDate(birthday, 'yyyy-MM-dd'),'yyyy') AS mes
#         ;
# grouped = GROUP datos BY (mes);
# conteo = FOREACH grouped GENERATE group, COUNT(datos.mes);
# STORE conteo INTO 'output' USING PigStorage(',');
# Out:
#  --
#  -- >>> Escriba su respuesta a partir de este punto <<<
#  --
#  datos = FOREACH u GENERATE
#          birthday AS fecha,
#         ToString(ToDate(birthday, 'yyyy-MM-dd'),'yyyy') AS mes
#         ;
#  grouped = GROUP datos BY (mes);
#  conteo = FOREACH grouped GENERATE group, COUNT(datos.mes);
#  STORE conteo INTO 'output' USING PigStorage(',');
# 2020-01-29 01:25:16,830 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-29 01:25:17,015 [JobControl] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-29 01:25:17,029 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-29 01:25:17,108 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-29 01:25:17,115 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-01-29 01:25:17,155 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local450248055_0002
# 2020-01-29 01:25:17,343 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1580261117206/pig-0.17.0-core-h2.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/pig-0.17.0-core-h2.jar
# 2020-01-29 01:25:17,351 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1580261117206/pig-0.17.0-core-h2.jar /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/pig-0.17.0-core-h2.jar' failed 1 with: ln: failed to create symbolic link '/datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/pig-0.17.0-core-h2.jar': Protocol error
#
# 2020-01-29 01:25:17,351 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1580261117206/pig-0.17.0-core-h2.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/pig-0.17.0-core-h2.jar
# 2020-01-29 01:25:17,351 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp-1423955626/tmp-240912768/pig-0.17.0-core-h2.jar as file:/tmp/hadoop-root/mapred/local/1580261117206/pig-0.17.0-core-h2.jar
# 2020-01-29 01:25:17,353 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1580261117207/automaton-1.11-8.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/automaton-1.11-8.jar
# 2020-01-29 01:25:17,361 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1580261117207/automaton-1.11-8.jar /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/automaton-1.11-8.jar' failed 1 with: ln: failed to create symbolic link '/datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/automaton-1.11-8.jar': Protocol error
#
# 2020-01-29 01:25:17,361 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1580261117207/automaton-1.11-8.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/automaton-1.11-8.jar
# 2020-01-29 01:25:17,361 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp-1423955626/tmp650532106/automaton-1.11-8.jar as file:/tmp/hadoop-root/mapred/local/1580261117207/automaton-1.11-8.jar
# 2020-01-29 01:25:17,363 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1580261117208/antlr-runtime-3.4.jar <- /datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=18
# 		Map output records=18
# 		Map output bytes=216
# 		Map output materialized bytes=109
# 		Input split bytes=402
# 		Combine input records=18
# 		Combine output records=7
# 		Spilled Records=7
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=398983168
# 	File Input Format Counters
# 		Bytes Read=0
# 2020-01-29 01:25:17,857 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local450248055_0002_m_000000_0
# 2020-01-29 01:25:17,857 [Thread-47] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2020-01-29 01:25:17,866 [Thread-47] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2020-01-29 01:25:17,867 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local450248055_0002_r_000000_0
# 2020-01-29 01:25:17,898 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-01-29 01:25:17,898 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-01-29 01:25:17,902 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2020-01-29 01:25:17,907 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@3a33bf8a
# 2020-01-29 01:25:17,929 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=652528832, maxSingleShuffleLimit=163132208, mergeThreshold=430669056, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2020-01-29 01:25:17,939 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local450248055_0002_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2020-01-29 01:25:18,012 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#1 about to shuffle output of map attempt_local450248055_0002_m_000000_0 decomp: 105 len: 109 to MEMORY
# 2020-01-29 01:25:18,018 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 105 bytes from map-output for attempt_local450248055_0002_m_000000_0
# 2020-01-29 01:25:18,021 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 105, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->105
# 2020-01-29 01:25:18,024 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2020-01-29 01:25:18,026 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2020-01-29 01:25:18,026 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2020-01-29 01:25:18,037 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2020-01-29 01:25:18,038 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 96 bytes
# 2020-01-29 01:25:18,040 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 105 bytes to disk to satisfy reduce memory limit
# 2020-01-29 01:25:18,040 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 109 bytes from disk
# 2020-01-29 01:25:18,041 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2020-01-29 01:25:18,041 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2020-01-29 01:25:18,042 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 96 bytes
# 2020-01-29 01:25:18,043 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2020-01-29 01:25:18,050 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-01-29 01:25:18,050 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-01-29 01:25:18,112 [pool-6-thread-1] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2020-01-29 01:25:18,123 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local450248055_0002_r_000000_0 is done. And is in the process of committing
# 2020-01-29 01:25:18,143 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2020-01-29 01:25:18,143 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local450248055_0002_r_000000_0 is allowed to commit now
# 2020-01-29 01:25:18,183 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local450248055_0002_r_000000_0' to file:/datalake/evaluacion-final-jomontoyac-master/02-pig-50/q31-10/output/_temporary/0/task_local450248055_0002_r_000000
# 2020-01-29 01:25:18,185 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2020-01-29 01:25:18,186 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local450248055_0002_r_000000_0' done.
# 2020-01-29 01:25:18,187 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local450248055_0002_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=11604048
# 		FILE: Number of bytes written=24164615
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=7
# 		Reduce shuffle bytes=109
# 		Reduce input records=7
# 		Reduce output records=7
# 		Spilled Records=7
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=398983168
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2020-01-29 01:25:18,187 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local450248055_0002_r_000000_0
# 2020-01-29 01:25:18,187 [Thread-47] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2020-01-29 01:25:22,850 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-29 01:25:22,852 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-29 01:25:22,853 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-29 01:25:22,871 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-29 01:25:22,873 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-29 01:25:22,874 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
