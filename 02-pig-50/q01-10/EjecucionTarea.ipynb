# %%
# %load_ext bigdata
# !rm -rf output
# Out:
# The bigdata extension is already loaded. To reload it, use:
#   %reload_ext bigdata

# %%
# %%pig
# u = LOAD 'data.tsv' USING PigStorage('\t')
#     AS (letter:CHARARRAY,
#         date:CHARARRAY,
#        num:INT);
# Out:
#  u = LOAD 'data.tsv' USING PigStorage('\t')
#     AS (letter:CHARARRAY,
#         date:CHARARRAY,
#        num:INT);

# %%
# %%pig
# y = GROUP u BY $0;
# z = FOREACH y GENERATE $0, COUNT(u);
# STORE z INTO 'output';
# Out:
#  y = GROUP u BY $0;
#  z = FOREACH y GENERATE $0, COUNT(u);
#  STORE z INTO 'output';
# 2020-01-23 02:14:19,118 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-23 02:14:19,196 [JobControl] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-01-23 02:14:19,202 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-23 02:14:19,265 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-23 02:14:19,268 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# ...
